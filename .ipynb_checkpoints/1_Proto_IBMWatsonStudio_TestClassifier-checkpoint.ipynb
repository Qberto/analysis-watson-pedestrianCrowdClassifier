# %% [markdown]
# # Test Watson Classifiers
#
# ###### Author: Alberto Nieto
# ###### Organization: Esri
# ###### Date: June, 2017

# %% [markdown]
# # Pseudocode

# %% [markdown]
# Goal: To run Watson classifiers on a few test images to validate that the classifiers are functioning.
#
# Procedure:
# 1. Authenticate
# 2. Retrieve models
# 3. Pass sample images to models
# 4. Confirm classification returned is nominal

# %% [markdown]
# # 1. Preparation and Authenticate

# %%
import os
from watson_developer_cloud import VisualRecognitionV3
import json
from IPython.display import Image
from IPython.core.display import HTML

# %%
visual_recognition = VisualRecognitionV3(
    '2018-03-19',
    iam_api_key=os.environ['BLUEMIX_API_KEY'])

# %% [markdown]
# # 2. Retrieve Models

# %%
visual_recognition.list_classifiers(verbose=True)
# Out:
# {'classifiers': [{'classes': [{'class': 'low'},
#     {'class': 'medium'},
#     {'class': 'high'}],
#    'classifier_id': 'Esri_Classification_CobbCounty_371717976',
#    'core_ml_enabled': True,
#    'created': '2018-06-26T15:08:09.890Z',
#    'name': 'Esri_Classification_CobbCounty_Cam130',
#    'owner': '52d3c878-5f0a-44c6-b191-358d19be7bc5',
#    'status': 'ready',
#    'updated': '2018-06-26T15:08:09.890Z'},
#   {'classes': [{'class': 'low'}, {'class': 'medium'}, {'class': 'high'}],
#    'classifier_id': 'Esri_Classification_CobbCounty_1256542849',
#    'core_ml_enabled': True,
#    'created': '2018-06-26T15:00:48.899Z',
#    'name': 'Esri_Classification_CobbCounty_Cam128',
#    'owner': '52d3c878-5f0a-44c6-b191-358d19be7bc5',
#    'status': 'ready',
#    'updated': '2018-06-26T15:00:48.899Z'},
#   {'classes': [{'class': 'low'}, {'class': 'medium'}, {'class': 'high'}],
#    'classifier_id': 'Esri_Classification_CobbCounty_361684145',
#    'core_ml_enabled': True,
#    'created': '2018-06-26T15:06:56.039Z',
#    'name': 'Esri_Classification_CobbCounty_Cam129',
#    'owner': '52d3c878-5f0a-44c6-b191-358d19be7bc5',
#    'status': 'ready',
#    'updated': '2018-06-26T15:06:56.039Z'}]}

# %%
classifier_name = 'Esri_Classification_CobbCounty_Cam128'

# %%
classifier_id = None

for classifier in visual_recognition.list_classifiers()['classifiers']:    
    if classifier['name'] == classifier_name:
        classifier_id = classifier['classifier_id']

print(classifier_id)
# Out:
# Esri_Classification_CobbCounty_1256542849

# %% [markdown]
# # 3. Pass sample images to models
# # +
# # 4. Confirm classification returned is nominal

# %%
test_images_dir = "{0}\\TestData\\128".format(os.getcwd())
high_dir = "{0}\\{1}".format(test_images_dir, "High")
med_dir = "{0}\\{1}".format(test_images_dir, "Medium")
low_dir = "{0}\\{1}".format(test_images_dir, "Low")
high_img_path = "{0}\\{1}".format(high_dir, os.listdir(high_dir)[0])
med_img_path = "{0}\\{1}".format(med_dir, os.listdir(med_dir)[0])
low_img_path = "{0}\\{1}".format(low_dir, os.listdir(low_dir)[0])

# %% [markdown]
# #### Low Pedestrian Density

# %%
Image(filename= low_img_path)

# %%
with open(low_img_path, 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.0',
        classifier_ids=classifier_id)
    print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "Esri_Classification_CobbCounty_1256542849",
#           "name": "Esri_Classification_CobbCounty_Cam128",
#           "classes": [
#             {
#               "class": "high",
#               "score": 0
#             },
#             {
#               "class": "low",
#               "score": 0.908
#             },
#             {
#               "class": "medium",
#               "score": 0
#             }
#           ]
#         }
#       ],
#       "image": "C:\\Users\\anieto\\Documents\\GitHub\\watson-crowd-classifier\\TestData\\128\\Low\\Cam_12818-06-24_15-45-29-07.jpg"
#     }
#   ],
#   "images_processed": 1,
#   "custom_classes": 3
# }

# %% [markdown]
# #### Medium Pedestrian Density

# %%
Image(filename= med_img_path)

# %%
with open(med_img_path, 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.0',
        classifier_ids=classifier_id)
    print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "Esri_Classification_CobbCounty_1256542849",
#           "name": "Esri_Classification_CobbCounty_Cam128",
#           "classes": [
#             {
#               "class": "high",
#               "score": 0.001
#             },
#             {
#               "class": "low",
#               "score": 0.898
#             },
#             {
#               "class": "medium",
#               "score": 0.055
#             }
#           ]
#         }
#       ],
#       "image": "C:\\Users\\anieto\\Documents\\GitHub\\watson-crowd-classifier\\TestData\\128\\Medium\\Cam_12818-06-24_15-55-59-05.jpg"
#     }
#   ],
#   "images_processed": 1,
#   "custom_classes": 3
# }

# %% [markdown]
# #### High Pedestrian Density

# %%
Image(filename= high_img_path)

# %%
with open(high_img_path, 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.0',
        classifier_ids=classifier_id)
    print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "Esri_Classification_CobbCounty_1256542849",
#           "name": "Esri_Classification_CobbCounty_Cam128",
#           "classes": [
#             {
#               "class": "high",
#               "score": 0.906
#             },
#             {
#               "class": "low",
#               "score": 0
#             },
#             {
#               "class": "medium",
#               "score": 0.012
#             }
#           ]
#         }
#       ],
#       "image": "C:\\Users\\anieto\\Documents\\GitHub\\watson-crowd-classifier\\TestData\\128\\High\\Cam_12818-06-24_16-45-29-06.jpg"
#     }
#   ],
#   "images_processed": 1,
#   "custom_classes": 3
# }
